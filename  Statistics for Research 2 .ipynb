# %% [markdown]
# Importing libraries and dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

Df=pd.read_csv(r'/content/Heart_Disease_Prediction.csv')
Df
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
# ...

# %% [markdown]
# Statistical information of Dataset

# %%
Df.describe()
# Out:
#               Age         Sex  Chest pain type          BP  Cholesterol  \
# count  270.000000  270.000000       270.000000  270.000000   270.000000
# mean    54.433333    0.677778         3.174074  131.344444   249.659259
# std      9.109067    0.468195         0.950090   17.861608    51.686237
# min     29.000000    0.000000         1.000000   94.000000   126.000000
# 25%     48.000000    0.000000         3.000000  120.000000   213.000000
# 50%     55.000000    1.000000         3.000000  130.000000   245.000000
# 75%     61.000000    1.000000         4.000000  140.000000   280.000000
# max     77.000000    1.000000         4.000000  200.000000   564.000000
#
#        FBS over 120  EKG results      Max HR  Exercise angina  ST depression  \
# count    270.000000   270.000000  270.000000       270.000000      270.00000
# mean       0.148148     1.022222  149.677778         0.329630        1.05000
# std        0.355906     0.997891   23.165717         0.470952        1.14521
# ...

# %%
Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      270 non-null    int64
#  1   Sex                      270 non-null    int64
#  2   Chest pain type          270 non-null    int64
#  3   BP                       270 non-null    int64
#  4   Cholesterol              270 non-null    int64
#  5   FBS over 120             270 non-null    int64
#  6   EKG results              270 non-null    int64
#  7   Max HR                   270 non-null    int64
#  8   Exercise angina          270 non-null    int64
#  9   ST depression            270 non-null    float64
#  10  Slope of ST              270 non-null    int64
#  11  Number of vessels fluro  270 non-null    int64
#  12  Thallium                 270 non-null    int64
#  13  Heart Disease            270 non-null    object
# ...

# %%
Df.dtypes
# Out:
# Age                          int64
# Sex                          int64
# Chest pain type              int64
# BP                           int64
# Cholesterol                  int64
# FBS over 120                 int64
# EKG results                  int64
# Max HR                       int64
# Exercise angina              int64
# ST depression              float64
# Slope of ST                  int64
# Number of vessels fluro      int64
# Thallium                     int64
# Heart Disease               object
# dtype: object

# %%
Df.shape
# Out:
# (270, 13)

# %% [markdown]
# Missing Values

# %%
Df.isna ().sum ()
# Out:
# Age                        0
# Sex                        0
# Chest pain type            0
# BP                         0
# Cholesterol                0
# FBS over 120               0
# EKG results                0
# Max HR                     0
# Exercise angina            0
# ST depression              0
# Slope of ST                0
# Number of vessels fluro    0
# Thallium                   0
# Heart Disease              0
# dtype: int64

# %%
Df.head(10)
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
# 5   65    1                4  120          177             0            0
# 6   56    1                3  130          256             1            2
# 7   59    1                4  110          239             0            2
# 8   60    1                4  140          293             0            2
# 9   63    0                4  150          407             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# ...

# %%
Df['Heart Disease'].value_counts()
# Out:
# Absence     150
# Presence    120
# Name: Heart Disease, dtype: int64

# %%
Df ['Heart Disease'].replace({'Absence':'0','Presence':'1'})
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 265    0
# 266    0
# 267    0
# 268    0
# 269    1
# Name: Heart Disease, Length: 270, dtype: object

# %%
Df.set_index ('Heart Disease',inplace=True)
Df
# Out:
#                Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  \
# Heart Disease
# Presence        70    1                4  130          322             0
# Absence         67    0                3  115          564             0
# Presence        57    1                2  124          261             0
# Absence         64    1                4  128          263             0
# Absence         74    0                2  120          269             0
# ...            ...  ...              ...  ...          ...           ...
# Absence         52    1                3  172          199             1
# Absence         44    1                2  120          263             0
# Absence         56    0                2  140          294             0
# Absence         57    1                4  140          192             0
# Presence        67    1                4  160          286             0
#
#                EKG results  Max HR  Exercise angina  ST depression  \
# ...

# %% [markdown]
# Parametric Statistical calculations

# %%
Df.mean ()
# Out:
# Age                         54.433333
# Sex                          0.677778
# Chest pain type              3.174074
# BP                         131.344444
# Cholesterol                249.659259
# FBS over 120                 0.148148
# EKG results                  1.022222
# Max HR                     149.677778
# Exercise angina              0.329630
# ST depression                1.050000
# Slope of ST                  1.585185
# Number of vessels fluro      0.670370
# Thallium                     4.696296
# dtype: float64

# %%
Df.median ()
# Out:
# Age                         55.0
# Sex                          1.0
# Chest pain type              3.0
# BP                         130.0
# Cholesterol                245.0
# FBS over 120                 0.0
# EKG results                  2.0
# Max HR                     153.5
# Exercise angina              0.0
# ST depression                0.8
# Slope of ST                  2.0
# Number of vessels fluro      0.0
# Thallium                     3.0
# dtype: float64

# %%
#standard deviation
Std_dev=np.std (Df)
Std_dev
# Out:
# Age                         9.092182
# Sex                         0.467328
# Chest pain type             0.948329
# BP                         17.828501
# Cholesterol                51.590433
# FBS over 120                0.355247
# EKG results                 0.996042
# Max HR                     23.122778
# Exercise angina             0.470079
# ST depression               1.143087
# Slope of ST                 0.613251
# Number of vessels fluro     0.942147
# Thallium                    1.937062
# dtype: float64

# %% [markdown]
# Variance

# %%
Variance=np.var (Df)
Variance
# Out:
# Age                          82.667778
# Sex                           0.218395
# Chest pain type               0.899328
# BP                          317.855432
# Cholesterol                2661.572785
# FBS over 120                  0.126200
# EKG results                   0.992099
# Max HR                      534.662840
# Exercise angina               0.220974
# ST depression                 1.306648
# Slope of ST                   0.376077
# Number of vessels fluro       0.887641
# Thallium                      3.752209
# dtype: float64

# %%
Data_range=np.max (Df['BP'])-np.min(Df['BP'])
Data_range
# Out:
# 106

# %%
Data_range=np.max (Df['Thallium'])-np.min(Df['Thallium'])
Data_range
# Out:
# 4

# %% [markdown]
# Standard errors

# %%
Std_err =Df.sem ()
Std_err
# Out:
# Age                        0.554360
# Sex                        0.028493
# Chest pain type            0.057821
# BP                         1.087023
# Cholesterol                3.145524
# FBS over 120               0.021660
# EKG results                0.060730
# Max HR                     1.409821
# Exercise angina            0.028661
# ST depression              0.069695
# Slope of ST                0.037391
# Number of vessels fluro    0.057444
# Thallium                   0.118105
# dtype: float64

# %% [markdown]
# NORMALITY TEST

# %% [markdown]
# 1.skewness

# %%
from scipy.stats import skew

Skewness=skew (Df)
Skewness
# Out:
# array([-0.16270485, -0.76082725, -0.87387764,  0.71859725,  1.17713449,
#         1.98088693, -0.0444545 , -0.52480028,  0.724859  ,  1.25586628,
#         0.54012879,  1.20315842,  0.2856696 ])

# %% [markdown]
# 2.Kurtosis

# %%
from scipy.stats import kurtosis

Kurtosis =kurtosis(Df)
Kurtosis
# Out:
# array([-0.55691862, -1.42114189, -0.31322484,  0.88395053,  4.78326838,
#         1.92391304, -1.99055371, -0.12331324, -1.47457943,  1.70476486,
#        -0.61753732,  0.27060298, -1.88774395])

# %% [markdown]
# Calculate  Correlation between parameters

# %%
Df.corr ()
# Out:
# <ipython-input-60-0d567c8447e9>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Df.corr ()
#                               Age       Sex  Chest pain type        BP  \
# Age                      1.000000 -0.094401         0.096920  0.273053
# Sex                     -0.094401  1.000000         0.034636 -0.062693
# Chest pain type          0.096920  0.034636         1.000000 -0.043196
# BP                       0.273053 -0.062693        -0.043196  1.000000
# Cholesterol              0.220056 -0.201647         0.090465  0.173019
# FBS over 120             0.123458  0.042140        -0.098537  0.155681
# EKG results              0.128171  0.039253         0.074325  0.116157
# Max HR                  -0.402215 -0.076101        -0.317682 -0.039136
# ...

# %% [markdown]
# Check the distribution of parameters

# %%
#plot the Correlation distribution
plt.figure(figsize=(8,8))
sns.heatmap (Df.corr ())
# Out:
# <Axes: >

# %%
#Distribution plot of all feature of dataset (numerical data)
sns.displot (Df,height=10,kind="kde",aspect=2)

# %%
sns.displot(Df)    #clearly plot or distribution

# %%
sns.distplot  (Df['Chest pain type'])
# Out:
# <ipython-input-25-862aacd065e0>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot  (Df['Chest pain type'])
# <Axes: xlabel='Chest pain type', ylabel='Density'>

# %%
#distribution of precipitation
sns.distplot  (Df ['BP'])
# Out:
# <ipython-input-21-b3ab9888f1c4>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot  (Df ['BP'])
# <Axes: xlabel='BP', ylabel='Density'>

# %%
sns.distplot (Df ['Cholesterol'])
# Out:
# <ipython-input-22-ca882fd5b821>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot (Df ['Cholesterol'])
# <Axes: xlabel='Cholesterol', ylabel='Density'>

# %%
sns.distplot (Df ['ST depression'])
# Out:
# <ipython-input-23-ab5c29815289>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot (Df ['ST depression'])
# <Axes: xlabel='ST depression', ylabel='Density'>

# %%
sns.distplot (Df ['Slope of ST'])
# Out:
# <ipython-input-26-ea0c74aa27de>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot (Df ['Slope of ST'])
# <Axes: xlabel='Slope of ST', ylabel='Density'>

# %% [markdown]
# Detect Outliers and remove them

# %%
sns.boxplot(Df)
# Out:
# <Axes: >

# %%
figure=plt.figure (figsize=(10,8))

#box plot to detect outliers
Df.boxplot(column='Cholesterol')

plt.show()

# %%
Df.boxplot  (column='BP')
plt.show ()

# %% [markdown]
# To detect and remove the outliers use Inter Quartile Range method  (IQR)

# %%
Q1=Df.BP.quantile(0.25)
Q1
# Out:
# 120.0

# %%
Median= Df.BP.median
Median
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.median of Heart Disease
# Presence    130
# Absence     115
# Presence    124
# Absence     128
# Absence     120
#            ...
# Absence     172
# Absence     120
# Absence     140
# Absence     140
# Presence    160
# Name: BP, Length: 270, dtype: int64>

# %%
Q3=Df.BP.quantile(0.75)
Q3
# Out:
# 140.0

# %%
IQR=Q3-Q1
IQR
# Out:
# 20.0

# %%
Upperl=Q3+(1.5*IQR)
Lowerl=Q1-(1.5*IQR)
Upperl,Lowerl
# Out:
# (170.0, 90.0)

# %% [markdown]
# Length of dataset after removing outliers

# %%
New_df=Df.loc [(Df['BP']>Upperl)|(Df ['BP']<Lowerl)]
len (New_df)
# Out:
# 9

# %% [markdown]
# Length of old dataset before removing the outliers

# %%
len (Df)
# Out:
# 270

# %% [markdown]
# Check the distribution after remove the outliers

# %%
sns.displot(New_df ['BP'])

# %% [markdown]
# HYPOTHESIS TESTS FOR PARAMETRIC STATISTICS

# %% [markdown]
# P values, significance level ,sample size and power

# %% [markdown]
# 1.Calculating the parametric statistical significance using T-test

# %%
from scipy.stats import ttest_ind

D1=New_df ['Cholesterol']
D2=New_df ['BP']

#compare the samples
Stat,p =ttest_ind (D1,D2)
print ('statistics =%.3f,p=%.3f'% (Stat,p))

#interpret

alpha=0.05
if p>alpha:
   print('same distribution  (fail to reject H0)')
else:
    print('different distribution (reject H0)')
# Out:
# statistics =6.304,p=0.000
# different distribution (reject H0)

# %% [markdown]
# 2.Parametric statistical Analysis of Variance

# %%
from scipy.stats import f_oneway

D1=New_df ['Slope of ST']
D2=New_df ['ST depression']

#compare the samples
Stat,p =f_oneway(D1,D2)
print ('statistics =%.3f,p=%.3f'% (Stat,p))

#interpret

alpha=0.05
if p>alpha:
   print('same distribution  (fail to reject H0)')
else:
    print('different distribution (reject H0)')
# Out:
# statistics =0.157,p=0.697
# same distribution  (fail to reject H0)

# %% [markdown]
# To calculate the Effect Size, use Pearson Correlation Significant

# %%
from scipy.stats import pearsonr

corr, _ =pearsonr (D1,D2)
print  ('Pearson Correlation :%.3f'%corr)
# Out:
# Pearson Correlation :0.844

# %% [markdown]
# Calculate the Sample Size

# %%
from statsmodels.stats.power import TTestIndPower

power_analysis =TTestIndPower()
#calculate the samplesize
Sample_size=power_analysis.solve_power (effect_size=0.2,alpha=0.05,power=0.8,alternative ='two-sided')
Sample_size
# Out:
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_continuous_distns.py:6832: RuntimeWarning: invalid value encountered in _nct_sf
#   return np.clip(_boost._nct_sf(x, df, nc), 0, 1)
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_continuous_distns.py:6826: RuntimeWarning: invalid value encountered in _nct_cdf
#   return np.clip(_boost._nct_cdf(x, df, nc), 0, 1)
# 393.4056930002516

# %% [markdown]
# Calculate the Effect Size using Cohen's d Equation

# %%
Df['Slope of ST'].mean()
# Out:
# 1.5851851851851853

# %%
np.std (Df ['Slope of ST'])
# Out:
# 0.613251023283532

# %%
Df ['ST depression'].mean ()
# Out:
# 1.05

# %%
np.std (Df ['ST depression'])
# Out:
# 1.1430871131056233

# %%
Mu1=1.58 #gp1 avg value
Mu2=1.05  #gp2 avg value

s1=0.61   #gp1 std_dev
s2=1.41   #gp2 std_dev
n1=270   #gp1 sample size
n2=270   #gp2 sample size

#calculate pooled standard deviation
S=np.sqrt ((n1-1)*s1+(n2-1)*s2/(n1+n2-2))
#calculate cohend effect size
d=(Mu1-Mu2)/S

print  ('Effect size is :',round (d, 2))
# Out:
# Effect size is : 0.04

# %% [markdown]
# Calculate the Significance level

# %%
power_analysis =TTestIndPower()
#Significance level is the alpha
Alpha=power_analysis.solve_power (effect_size=0.2,ratio=1,alpha=0.05,power=0.8,alternative ='two-sided')
Alpha
# Out:
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_continuous_distns.py:6832: RuntimeWarning: invalid value encountered in _nct_sf
#   return np.clip(_boost._nct_sf(x, df, nc), 0, 1)
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_continuous_distns.py:6826: RuntimeWarning: invalid value encountered in _nct_cdf
#   return np.clip(_boost._nct_cdf(x, df, nc), 0, 1)
# 393.4056930002516

# %% [markdown]
# Exploratory Factor Analysis

# %%
pip install factor_analyzer
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.5/42.5 kB 3.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.8/202.8 kB 12.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.8/98.8 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 65.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.5/468.5 kB 44.7 MB/s eta 0:00:00
# ...
#   Created wheel for factor_analyzer: filename=factor_analyzer-0.5.0-py2.py3-none-any.whl size=42486 sha256=59e68e0321ad8d93973a59e325c1cfd40ce36a7b0b23064c5dd796f04340324e
#   Stored in directory: /root/.cache/pip/wheels/74/a2/6c/26fb1addf1ce6c60a8cef8397f2999f0a1e6e2fcddc8abf33e
# Successfully built factor_analyzer
# ...

# %%
from factor_analyzer import FactorAnalyzer
#pip install factor_analyzer and create factor analyzer

Fa=FactorAnalyzer  (n_factors =6,rotation="varimax")

# %%
Fa.fit (Df)
loadings=Fa.loadings_

# %%
#get the loading eigenvalues
ev, v=Fa.get_eigenvalues()

xvals=range (1,Df.shape [1]+1)

# %%
plt.scatter(xvals,ev)
plt.plot (xvals,ev )
plt.xlabel ('Factors')
plt.ylabel  ('Eigenvalues')
plt.title  ('Scree Plot')
plt.grid()
plt.show ()
